# %% [markdown]
# # Parallelised Gust Response of a Simple HALE Aircraft
#
# This case demonstrates parallelisation of the ``simple_hale`` model using ``jax.pmap``. It performs a parameter sweep over gust length (and optionally gust amplitude), solving one dynamic aeroelastic response per case in parallel and plotting the root strains. On a MacBook Air M2, this runs at roughly 7 seconds per dynamic case when parallelised over 32 cases.

# %% [markdown]
# ## Configure JAX host device count
#
# ``jax.pmap`` requires one device per case. To parallelise the sweep on CPU, we force XLA to expose ``n_case`` host devices via the ``XLA_FLAGS`` environment variable. This must be set before importing ``jax``.

# %%
import os

# number of cases for the sweep
n_gust_length: int = 32
n_gust_amplitude: int = 1
n_case: int = n_gust_length * n_gust_amplitude

# force XLA to give one host device per case
# it isn't essential to have one core/thread per case, but it will likely be faster than having multiple cases share a single core/thread
os.environ["XLA_FLAGS"] = (
        os.environ.get("XLA_FLAGS", "")
        + f" --xla_force_host_platform_device_count={n_case} --xla_cpu_multi_thread_eigen=true"
).strip()

# %% [markdown]
# ## Imports
#
# JAX imports **must** occur after ``XLA_FLAGS`` is set.

# %%
from copy import deepcopy
import time

import matplotlib.pyplot as plt
import jax
from jax import numpy as jnp

from aegrad.aero.flowfields import Constant, OneMinusCosine
from aegrad.coupled import CoupledAeroelastic
from aegrad.models.simple_hale.simple_hale import generate_simple_hale

jax.config.update("jax_enable_x64", True)

assert jax.device_count() == n_case, (
    f"Expected {n_case} devices, got {jax.device_count()}"
)

# %% [markdown]
# ## Case parametrisation
#
# Define the free-stream velocity, the physical simulation time, and the sweep ranges. If ``n_gust_amplitude > 1``, amplitudes will also be swept.

# %%
u_inf_mag: float = 10.0  # free-stream velocity magnitude
physical_time: float = 10.0

gust_lengths = jnp.linspace(0.1 * u_inf_mag, 5.0 * u_inf_mag, n_gust_length)
gust_amplitudes = (
    jnp.linspace(0.0, 0.5, n_gust_amplitude) if n_gust_amplitude > 1 else [0.3]
)

# %% [markdown]
# ## Build the trimmed base aircraft
#
# Construct a HALE aircraft in a constant free-stream and trim it. This is used as the initial condition for all gust cases. Note that the compilation can take ~1 minute.

# %%
const_flowfield = Constant(
    u_inf=jnp.array((u_inf_mag, 0.0, 0.0)),
    rho=1.225,
    relative_motion=True,
)

base_hale = generate_simple_hale(flowfield=const_flowfield, sigma_wing=1.5)
n_tstep = int(physical_time / float(base_hale.aero.dt)) + 1

static_sol, trim_vars = base_hale.trim(
    prescribed_dofs=jnp.arange(6),
    zero_force_dofs=(0, 2, 4),  # balance drag, lift, and pitching moment
    trim_cs="elevator",
    thrust_nodes="thrust",
    trim_orientation="y",
    method="finite_difference",
    horseshoe=False,
)
# Out:
# +------------------------- Trim (Broyden, FD bootstrap) --------------------------+
# | Iteration                |     0                                                |
# | Control surface angles (deg) | [elevator]: -2.39                                |
# | Thrust force (N)         | [thrust]: 36.30                                      |
# | Body Euler angles (deg)  | [y]:  2.82                                           |
# | Residual clamp force (N) | [f0]: -24.52  [f1]: -162.81  [f2]: 126.38                |
# | Iteration                |     1                                                |
# | Control surface angles (deg) | [elevator]: -2.67                                |
# | Thrust force (N)         | [thrust]: 26.90                                      |
# | Body Euler angles (deg)  | [y]:  3.31                                           |
# | Residual clamp force (N) | [f0]: -17.05  [f1]: -86.67  [f2]: 98.43                |
# | Iteration                |     2                                                |
# | Thrust force (N)         | [thrust]: -4.63                                      |
# | Control surface angles (deg) | [elevator]: -2.92                                |
# | Body Euler angles (deg)  | [y]:  4.20                                           |
# | Residual clamp force (N) | [f0]:  8.80  [f1]: 37.15  [f2]:  8.87                |
# | Iteration                |     3                                                |
# | Control surface angles (deg) | [elevator]: -2.77                                |
# | Body Euler angles (deg)  | [y]:  3.93                                           |
# | Thrust force (N)         | [thrust]:  5.10                                      |
# | Residual clamp force (N) | [f0]:  0.95  [f1]:  2.57  [f2]: 28.69                |
# | Iteration                |     4                                                |
# | Control surface angles (deg) | [elevator]: -2.69                                |
# | Thrust force (N)         | [thrust]:  6.04                                      |
# | Body Euler angles (deg)  | [y]:  3.89                                           |
# | Residual clamp force (N) | [f0]:  0.23  [f1]: -1.16  [f2]: 23.98                |
# | Iteration                |     5                                                |
# | Control surface angles (deg) | [elevator]: -2.62                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.30                                      |
# | Residual clamp force (N) | [f0]: -0.00  [f1]: -1.71  [f2]: 17.69                |
# | Iteration                |     6                                                |
# | Control surface angles (deg) | [elevator]: -2.59                                |
# | Thrust force (N)         | [thrust]:  6.29                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.03  [f1]: -1.37  [f2]: 14.03                |
# | Iteration                |     7                                                |
# | Control surface angles (deg) | [elevator]: -2.59                                |
# | Thrust force (N)         | [thrust]:  6.31                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.03  [f1]: -1.42  [f2]: 14.32                |
# | Iteration                |     8                                                |
# | Control surface angles (deg) | [elevator]: -2.55                                |
# | Thrust force (N)         | [thrust]:  6.18                                      |
# | Body Euler angles (deg)  | [y]:  3.89                                           |
# | Residual clamp force (N) | [f0]:  0.05  [f1]: -0.84  [f2]:  9.31                |
# | Iteration                |     9                                                |
# | Control surface angles (deg) | [elevator]: -2.55                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.25                                      |
# | Residual clamp force (N) | [f0]:  0.05  [f1]: -0.91  [f2]:  9.21                |
# | Iteration                |    10                                                |
# | Control surface angles (deg) | [elevator]: -2.75                                |
# | Body Euler angles (deg)  | [y]:  3.94                                           |
# | Thrust force (N)         | [thrust]: -6.00                                      |
# | Residual clamp force (N) | [f0]: 12.02  [f1]:  4.40  [f2]: 24.45                |
# | Iteration                |    11                                                |
# | Control surface angles (deg) | [elevator]: -2.55                                |
# | Thrust force (N)         | [thrust]:  5.07                                      |
# | Body Euler angles (deg)  | [y]:  3.89                                           |
# | Residual clamp force (N) | [f0]:  1.16  [f1]: -0.19  [f2]:  8.67                |
# | Iteration                |    12                                                |
# | Control surface angles (deg) | [elevator]: -2.52                                |
# | Thrust force (N)         | [thrust]:  6.13                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]:  0.09  [f1]: -0.50  [f2]:  5.62                |
# | Iteration                |    13                                                |
# | Control surface angles (deg) | [elevator]: -2.50                                |
# | Thrust force (N)         | [thrust]:  6.21                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]:  0.03  [f1]: -0.42  [f2]:  4.20                |
# | Iteration                |    14                                                |
# | Control surface angles (deg) | [elevator]: -2.49                                |
# | Thrust force (N)         | [thrust]:  6.24                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.04  [f1]: -0.30  [f2]:  2.89                |
# | Iteration                |    15                                                |
# | Control surface angles (deg) | [elevator]: -2.49                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.22                                      |
# | Residual clamp force (N) | [f0]: -0.01  [f1]: -0.29  [f2]:  2.81                |
# | Iteration                |    16                                                |
# | Control surface angles (deg) | [elevator]: -2.48                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.22                                      |
# | Residual clamp force (N) | [f0]: -0.01  [f1]: -0.22  [f2]:  2.17                |
# | Iteration                |    17                                                |
# | Control surface angles (deg) | [elevator]: -2.37                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.11                                      |
# | Residual clamp force (N) | [f0]:  0.01  [f1]:  1.13  [f2]: -11.11                |
# | Iteration                |    18                                                |
# | Control surface angles (deg) | [elevator]: -2.44                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.17                                      |
# | Residual clamp force (N) | [f0]:  0.01  [f1]:  0.30  [f2]: -2.96                |
# | Iteration                |    19                                                |
# | Control surface angles (deg) | [elevator]: -2.53                                |
# | Thrust force (N)         | [thrust]:  6.27                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.04  [f1]: -0.80  [f2]:  7.83                |
# | Iteration                |    20                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.20                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]:  0.02  [f1]: -0.00  [f2]:  0.04                |
# | Iteration                |    21                                                |
# | Control surface angles (deg) | [elevator]: -2.48                                |
# | Thrust force (N)         | [thrust]:  6.22                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.01  [f1]: -0.15  [f2]:  1.49                |
# | Iteration                |    22                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.21                                      |
# | Residual clamp force (N) | [f0]:  0.00  [f1]: -0.09  [f2]:  0.87                |
# | Iteration                |    23                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.21                                      |
# | Residual clamp force (N) | [f0]: -0.02  [f1]: -0.08  [f2]:  0.78                |
# | Iteration                |    24                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.21                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.03  [f1]: -0.07  [f2]:  0.67                |
# | Iteration                |    25                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.22                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]:  0.01  [f1]: -0.08  [f2]:  0.72                |
# | Iteration                |    26                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.21                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.01  [f1]: -0.06  [f2]:  0.56                |
# | Iteration                |    27                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.22                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.00  [f1]: -0.05  [f2]:  0.48                |
# | Iteration                |    28                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.22                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.02  [f1]: -0.03  [f2]:  0.28                |
# | Iteration                |    29                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.22                                      |
# | Residual clamp force (N) | [f0]: -0.01  [f1]: -0.04  [f2]:  0.39                |
# | Iteration                |    30                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.21                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.00  [f1]: -0.04  [f2]:  0.39                |
# | Iteration                |    31                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.21                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]:  0.01  [f1]: -0.03  [f2]:  0.31                |
# | Iteration                |    32                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.21                                      |
# | Residual clamp force (N) | [f0]: -0.01  [f1]: -0.03  [f2]:  0.27                |
# | Iteration                |    33                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.21                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.02  [f1]: -0.02  [f2]:  0.23                |
# | Iteration                |    34                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.21                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.02  [f1]: -0.03  [f2]:  0.24                |
# | Iteration                |    35                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.21                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.01  [f1]: -0.02  [f2]:  0.20                |
# | Iteration                |    36                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.22                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.01  [f1]: -0.01  [f2]:  0.12                |
# | Iteration                |    37                                                |
# | Control surface angles (deg) | [elevator]: -2.46                                |
# | Thrust force (N)         | [thrust]:  6.22                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.04  [f1]:  0.03  [f2]: -0.33                |
# | Iteration                |    38                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.21                                      |
# | Residual clamp force (N) | [f0]:  0.00  [f1]: -0.01  [f2]:  0.13                |
# | Iteration                |    39                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.22                                      |
# | Residual clamp force (N) | [f0]: -0.02  [f1]: -0.01  [f2]:  0.08                |
# | Iteration                |    40                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.21                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.00  [f1]: -0.01  [f2]:  0.09                |
# | Iteration                |    41                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.21                                      |
# | Residual clamp force (N) | [f0]: -0.01  [f1]: -0.01  [f2]:  0.07                |
# | Iteration                |    42                                                |
# | Thrust force (N)         | [thrust]:  6.21                                      |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.01  [f1]: -0.01  [f2]:  0.07                |
# | Iteration                |    43                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.22                                      |
# | Residual clamp force (N) | [f0]: -0.01  [f1]: -0.01  [f2]:  0.06                |
# | Iteration                |    44                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.21                                      |
# | Residual clamp force (N) | [f0]: -0.03  [f1]: -0.01  [f2]:  0.11                |
# | Iteration                |    45                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.22                                      |
# | Residual clamp force (N) | [f0]: -0.03  [f1]: -0.00  [f2]:  0.03                |
# | Iteration                |    46                                                |
# | Control surface angles (deg) | [elevator]: -2.48                                |
# | Thrust force (N)         | [thrust]:  6.20                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]:  0.00  [f1]: -0.12  [f2]:  1.14                |
# | Iteration                |    47                                                |
# | Control surface angles (deg) | [elevator]: -2.48                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.20                                      |
# | Residual clamp force (N) | [f0]:  0.00  [f1]: -0.12  [f2]:  1.11                |
# | Iteration                |    48                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.20                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]:  0.01  [f1]: -0.08  [f2]:  0.81                |
# | Iteration                |    49                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.20                                      |
# | Residual clamp force (N) | [f0]:  0.01  [f1]: -0.07  [f2]:  0.69                |
# | Iteration                |    50                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.20                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]:  0.02  [f1]: -0.05  [f2]:  0.51                |
# | Iteration                |    51                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.20                                      |
# | Residual clamp force (N) | [f0]:  0.01  [f1]: -0.05  [f2]:  0.52                |
# | Iteration                |    52                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.20                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.01  [f1]: -0.04  [f2]:  0.41                |
# | Iteration                |    53                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.20                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]:  0.02  [f1]: -0.04  [f2]:  0.35                |
# | Iteration                |    54                                                |
# | Thrust force (N)         | [thrust]:  6.20                                      |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]:  0.02  [f1]: -0.03  [f2]:  0.29                |
# | Iteration                |    55                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.20                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.01  [f1]: -0.05  [f2]:  0.43                |
# | Iteration                |    56                                                |
# | Thrust force (N)         | [thrust]:  6.20                                      |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.01  [f1]: -0.03  [f2]:  0.29                |
# | Iteration                |    57                                                |
# | Control surface angles (deg) | [elevator]: -2.46                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.19                                      |
# | Residual clamp force (N) | [f0]:  0.01  [f1]:  0.03  [f2]: -0.26                |
# | Iteration                |    58                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.20                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.02  [f1]:  0.00  [f2]: -0.01                |
# | Iteration                |    59                                                |
# | Control surface angles (deg) | [elevator]: -2.46                                |
# | Thrust force (N)         | [thrust]:  6.19                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.00  [f1]:  0.01  [f2]: -0.10                |
# | Iteration                |    60                                                |
# | Control surface angles (deg) | [elevator]: -2.46                                |
# | Thrust force (N)         | [thrust]:  6.19                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.00  [f1]:  0.01  [f2]: -0.08                |
# | Iteration                |    61                                                |
# | Control surface angles (deg) | [elevator]: -2.46                                |
# | Thrust force (N)         | [thrust]:  6.19                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.00  [f1]:  0.01  [f2]: -0.08                |
# | Iteration                |    62                                                |
# | Control surface angles (deg) | [elevator]: -2.46                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.19                                      |
# | Residual clamp force (N) | [f0]: -0.00  [f1]:  0.01  [f2]: -0.06                |
# | Iteration                |    63                                                |
# | Control surface angles (deg) | [elevator]: -2.46                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.19                                      |
# | Residual clamp force (N) | [f0]:  0.00  [f1]:  0.01  [f2]: -0.05                |
# | Iteration                |    64                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.19                                      |
# | Residual clamp force (N) | [f0]:  0.01  [f1]:  0.00  [f2]: -0.05                |
# | Iteration                |    65                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.19                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]:  0.00  [f1]:  0.00  [f2]: -0.04                |
# | Iteration                |    66                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.19                                      |
# | Residual clamp force (N) | [f0]:  0.02  [f1]:  0.00  [f2]: -0.02                |
# | Iteration                |    67                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.19                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]:  0.02  [f1]:  0.00  [f2]: -0.03                |
# | Iteration                |    68                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.19                                      |
# | Residual clamp force (N) | [f0]: -0.00  [f1]:  0.00  [f2]: -0.04                |
# | Iteration                |    69                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.19                                      |
# | Residual clamp force (N) | [f0]:  0.01  [f1]:  0.00  [f2]: -0.03                |
# | Iteration                |    70                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.19                                      |
# | Residual clamp force (N) | [f0]: -0.00  [f1]:  0.00  [f2]: -0.03                |
# | Iteration                |    71                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.19                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]:  0.01  [f1]:  0.00  [f2]: -0.02                |
# | Iteration                |    72                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.19                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]: -0.01  [f1]:  0.00  [f2]: -0.03                |
# | Iteration                |    73                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.19                                      |
# | Residual clamp force (N) | [f0]:  0.03  [f1]:  0.00  [f2]: -0.01                |
# | Iteration                |    74                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Thrust force (N)         | [thrust]:  6.19                                      |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Residual clamp force (N) | [f0]:  0.01  [f1]:  0.00  [f2]: -0.01                |
# | Iteration                |    75                                                |
# | Control surface angles (deg) | [elevator]: -2.47                                |
# | Body Euler angles (deg)  | [y]:  3.88                                           |
# | Thrust force (N)         | [thrust]:  6.19                                      |
# | Residual clamp force (N) | [f0]: -0.01  [f1]:  0.00  [f2]: -0.00                |
# +---------------------------------------------------------------------------------+

# %% [markdown]
# ## Convert to a dynamic free-flying initial condition
#
# For the dynamic gust runs we switch from a static-aircraft/dynamic-freestream formulation to a dynamic-aircraft/static-freestream one, so that the aircraft is free to translate and rotate through the (stationary) gust.

# %%
dynamic_init = base_hale.initialise_dynamic(static_case=static_sol)

# %% [markdown]
# ## Build the stacked parallel case
#
# For each gust length/amplitude combination, we build a copy of the aircraft with a ``OneMinusCosine`` gust flowfield. The gust is positioned upstream of the aircraft by setting the gust offset with ``gust_x0``, such so that all cases begin with the aircraft outside the gust. The individual case pytrees are then stacked along a leading axis, producing a single pytree that ``jax.pmap`` will split across devices.

# %%
cases = []
for gust_length in gust_lengths:
    for gust_amplitude in gust_amplitudes:
        gust_flowfield = OneMinusCosine(
            u_inf=jnp.array((u_inf_mag, 0.0, 0.0)),
            rho=1.225,
            relative_motion=False,
            gust_length=gust_length,
            gust_amplitude=gust_amplitude * u_inf_mag,
            gust_x0=jnp.array((-2.0 * gust_length - 10.0, 0.0, 0.0)),
        )
        new_case = deepcopy(base_hale)
        new_case.aero.flowfield = gust_flowfield
        cases.append(new_case)

stacked_case = jax.tree_util.tree_map(lambda *xs: jnp.stack(xs), *cases)

# %% [markdown]
# ## Parallel dynamic solve
#
# ``solve`` runs a single dynamic case and returns the transient rotational (torsion + in/out-of-plane bending) strains at the root element. The use of ``jax.pmap`` maps the function over the leading axis of ``stacked_case``, so all cases execute concurrently. The reported time includes JIT compilation on the first call, which in some cases can be significant. Subsequent calls will be faster.
#
# The choice to only return the rotational strains is arbitrary. However, returning just a small subset of the full solution is often a good idea to reduce memory, as for instance this solution does not need to store the history of the aerodynamic states.
#
# Note that we here leave console prints on (which can be disabled using ``set_verbosity()``), which shows the progress of all cases. These prints are often of limited use in parallel, as they can be interleaved and hard to read. As we here use ``jax.pmap`` instead of ``jax.vmap``, some cases may finish considerably before others.

# %%
def solve(hale_: CoupledAeroelastic):
    dynamic_sol = hale_.dynamic_solve(
        init_case=dynamic_init, prescribed_dofs=None, n_tstep=n_tstep
    )
    # root strains: element 0, rotational strains only
    return dynamic_sol.structure.eps[:, 0, 3:]


t_start = time.time()
root_strains = jax.pmap(solve)(stacked_case)
jax.block_until_ready(root_strains)
t_end = time.time()

print(f"Time taken for {n_case} cases: {t_end - t_start:.2f} seconds")
print(f"Time per case: {(t_end - t_start) / n_case:.2f} seconds")
# Out:
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------- Dynamic Solve ---------------------------------------------+
# | Timestep |   Time    |    Iter     | Conv  | Rel Disp  | Abs Disp  | Rel Force | Abs Force | Load Step |
# +--------------------------------------------------------------------------------------------------------+
# +--------------------------------------------------------------------------------------------------------+
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 1        | 2.500e-02 | Struct: 6   | True  | 6.842e-06 | 8.301e-06 | 2.570e-04 | 1.043e+00 | 0         |
# | 1        | 2.500e-02 | FSI: 1      | True  | 3.989e-03 | 4.839e-03 | 8.984e-12 | 2.296e-10 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 2        | 5.000e-02 | Struct: 5   | True  | 5.093e-06 | 6.176e-06 | 3.500e-04 | 1.420e+00 | 0         |
# | 2        | 5.000e-02 | FSI: 3      | True  | 8.943e-04 | 1.085e-03 | 1.664e-01 | 4.277e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 3        | 7.500e-02 | Struct: 5   | True  | 4.382e-06 | 5.317e-06 | 5.232e-05 | 2.124e-01 | 0         |
# | 3        | 7.500e-02 | FSI: 5      | True  | 7.702e-04 | 9.344e-04 | 1.475e-01 | 3.716e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 4        | 1.000e-01 | Struct: 5   | True  | 4.230e-06 | 5.133e-06 | 1.300e-04 | 5.277e-01 | 0         |
# | 4        | 1.000e-01 | FSI: 4      | True  | 7.442e-04 | 9.031e-04 | 1.016e-01 | 2.582e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 5        | 1.250e-01 | Struct: 5   | True  | 5.070e-06 | 6.150e-06 | 4.523e-05 | 1.836e-01 | 0         |
# | 5        | 1.250e-01 | FSI: 2      | True  | 8.922e-04 | 1.082e-03 | 1.601e-01 | 4.146e+00 |           |
# | 391      | 9.775e+00 | Struct: 5   | True  | 4.972e-06 | 8.784e-06 | 1.487e-04 | 6.082e-01 | 0         |
# | 391      | 9.775e+00 | FSI: 1      | True  | 8.718e-04 | 1.540e-03 | 7.650e-03 | 2.123e-01 |           |
# | 392      | 9.800e+00 | Struct: 5   | True  | 5.681e-06 | 9.932e-06 | 1.419e-04 | 5.723e-01 | 0         |
# | 392      | 9.800e+00 | FSI: 1      | True  | 9.989e-04 | 1.746e-03 | 4.534e-03 | 1.247e-01 |           |
# | 392      | 9.800e+00 | Struct: 5   | True  | 4.899e-06 | 8.682e-06 | 1.199e-04 | 4.912e-01 | 0         |
# | 392      | 9.800e+00 | FSI: 1      | True  | 8.620e-04 | 1.528e-03 | 4.796e-03 | 1.332e-01 |           |
# | 393      | 9.825e+00 | Struct: 5   | True  | 5.635e-06 | 9.885e-06 | 1.607e-04 | 6.488e-01 | 0         |
# | 393      | 9.825e+00 | FSI: 1      | True  | 9.929e-04 | 1.742e-03 | 1.081e-02 | 2.981e-01 |           |
# | 393      | 9.825e+00 | Struct: 5   | True  | 4.895e-06 | 8.699e-06 | 1.666e-04 | 6.834e-01 | 0         |
# | 393      | 9.825e+00 | FSI: 1      | True  | 8.568e-04 | 1.523e-03 | 6.422e-03 | 1.784e-01 |           |
# | 394      | 9.850e+00 | Struct: 5   | True  | 5.604e-06 | 9.864e-06 | 1.382e-04 | 5.588e-01 | 0         |
# | 394      | 9.850e+00 | FSI: 1      | True  | 9.854e-04 | 1.734e-03 | 6.050e-03 | 1.671e-01 |           |
# | 394      | 9.850e+00 | Struct: 5   | True  | 4.840e-06 | 8.626e-06 | 1.548e-04 | 6.360e-01 | 0         |
# | 394      | 9.850e+00 | FSI: 1      | True  | 8.477e-04 | 1.511e-03 | 8.975e-03 | 2.499e-01 |           |
# | 395      | 9.875e+00 | Struct: 5   | True  | 5.528e-06 | 9.761e-06 | 1.370e-04 | 5.546e-01 | 0         |
# | 395      | 9.875e+00 | FSI: 1      | True  | 9.722e-04 | 1.717e-03 | 4.582e-03 | 1.266e-01 |           |
# | 395      | 9.875e+00 | Struct: 5   | True  | 4.756e-06 | 8.500e-06 | 1.180e-04 | 4.854e-01 | 0         |
# | 395      | 9.875e+00 | FSI: 1      | True  | 8.376e-04 | 1.497e-03 | 4.791e-03 | 1.335e-01 |           |
# | 396      | 9.900e+00 | Struct: 5   | True  | 5.462e-06 | 9.677e-06 | 1.592e-04 | 6.454e-01 | 0         |
# | 396      | 9.900e+00 | FSI: 1      | True  | 9.631e-04 | 1.706e-03 | 6.567e-03 | 1.816e-01 |           |
# | 396      | 9.900e+00 | Struct: 5   | True  | 4.734e-06 | 8.486e-06 | 1.343e-04 | 5.529e-01 | 0         |
# | 396      | 9.900e+00 | FSI: 1      | True  | 8.301e-04 | 1.488e-03 | 5.980e-03 | 1.667e-01 |           |
# | 397      | 9.925e+00 | Struct: 5   | True  | 5.432e-06 | 9.655e-06 | 1.466e-04 | 5.952e-01 | 0         |
# | 397      | 9.925e+00 | FSI: 1      | True  | 9.573e-04 | 1.701e-03 | 7.082e-03 | 1.962e-01 |           |
# | 397      | 9.925e+00 | Struct: 5   | True  | 4.677e-06 | 8.407e-06 | 1.164e-04 | 4.801e-01 | 0         |
# | 397      | 9.925e+00 | FSI: 1      | True  | 8.228e-04 | 1.479e-03 | 9.564e-03 | 2.672e-01 |           |
# | 398      | 9.950e+00 | Struct: 5   | True  | 5.376e-06 | 9.587e-06 | 1.311e-04 | 5.328e-01 | 0         |
# | 398      | 9.950e+00 | FSI: 1      | True  | 9.467e-04 | 1.688e-03 | 5.407e-03 | 1.499e-01 |           |
# | 398      | 9.950e+00 | Struct: 5   | True  | 4.625e-06 | 8.336e-06 | 1.141e-04 | 4.713e-01 | 0         |
# | 398      | 9.950e+00 | FSI: 1      | True  | 8.136e-04 | 1.466e-03 | 4.783e-03 | 1.338e-01 |           |
# | 399      | 9.975e+00 | Struct: 5   | True  | 5.314e-06 | 9.507e-06 | 1.311e-04 | 5.336e-01 | 0         |
# | 399      | 9.975e+00 | FSI: 1      | True  | 9.347e-04 | 1.672e-03 | 6.697e-03 | 1.858e-01 |           |
# | 399      | 9.975e+00 | Struct: 5   | True  | 4.588e-06 | 8.293e-06 | 1.286e-04 | 5.316e-01 | 0         |
# | 399      | 9.975e+00 | FSI: 1      | True  | 8.052e-04 | 1.455e-03 | 5.569e-03 | 1.558e-01 |           |
# | 400      | 1.000e+01 | Struct: 5   | True  | 4.509e-06 | 8.171e-06 | 1.643e-04 | 6.802e-01 | 0         |
# | 400      | 1.000e+01 | Struct: 5   | True  | 5.268e-06 | 9.453e-06 | 1.299e-04 | 5.294e-01 | 0         |
# | 400      | 1.000e+01 | FSI: 1      | True  | 7.974e-04 | 1.445e-03 | 1.063e-02 | 2.979e-01 |           |
# | 400      | 1.000e+01 | FSI: 1      | True  | 9.264e-04 | 1.662e-03 | 7.249e-03 | 2.016e-01 |           |
# Time taken for 32 cases: 268.53 seconds
# Time per case: 8.39 seconds

# %% [markdown]
# ## Plot the root strains
#
# For each strain component (torsion, in-plane bending, out-of-plane bending), plot the time history over all cases, coloured by gust length.

# %%
t = jnp.arange(n_tstep) * base_hale.aero.dt
cmap = plt.get_cmap("viridis")
norm = plt.Normalize(vmin=float(gust_lengths[0]), vmax=float(gust_lengths[-1]))
titles = ["Torsional", "In-plane bending", "Out-of-plane bending"]

for i_dir in range(3):
    fig, ax = plt.subplots()
    for i in range(n_case):
        ax.plot(
            t,
            root_strains[i, :, i_dir],
            color=cmap(i / max(n_case - 1, 1)),
        )
    ax.set_xlabel("Time [s]")
    ax.set_ylabel("Root Strain [m/m]")
    ax.set_title(f"{titles[i_dir]} strain at root")

    sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
    fig.colorbar(sm, ax=ax, label="Gust length [m]")
    plt.show()
